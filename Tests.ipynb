# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
from pprint import pprint

# %%
box_params = {0: [110, 406, 7, 312620, 242], 1: [76, 406, 10, 308560, 356], 2: [76, 406, 7, 215992, 460], 3: [110, 18, 10, 19800, 61], 4: [110, 18, 7, 13860, 168], 5: [110, 9, 24, 23760, 183], 6: [110, 9, 24, 23760, 184], 7: [110, 388, 5, 213400, 200], 8: [34, 234, 17, 135252, 286], 9: [110, 82, 19, 171380, 383], 10: [78, 85, 17, 112710, 416], 11: [78, 69, 17, 91494, 383], 
12: [76, 234, 10, 177840, 414], 13: [76, 234, 7, 124488, 106], 14: [110, 181, 19, 378290, 128], 15: [32, 154, 9, 44352, 415], 16: [32, 154, 8, 39424, 486], 17: [6, 406, 17, 41412, 495], 18: [47, 125, 19, 111625, 349], 19: [63, 125, 11, 86625, 275], 20: [63, 125, 8, 63000, 380], 21: [28, 340, 17, 161840, 144], 22: [28, 66, 17, 31416, 183]}
pprint(box_params.items())
# Out:
# dict_items([(0, [110, 406, 7, 312620, 242]), (1, [76, 406, 10, 308560, 356]), (2, [76, 406, 7, 215992, 460]), (3, [110, 18, 10, 19800, 61]), (4, [110, 18, 7, 13860, 168]), (5, [110, 9, 24, 23760, 183]), (6, [110, 9, 24, 23760, 184]), (7, [110, 388, 5, 213400, 200]), (8, [34, 234, 17, 135252, 286]), (9, [110, 82, 19, 171380, 383]), (10, [78, 85, 17, 112710, 416]), (11, [78, 69, 17, 91494, 383]), (12, [76, 234, 10, 177840, 414]), (13, [76, 234, 7, 124488, 106]), (14, [110, 181, 19, 378290, 128]), (15, [32, 154, 9, 44352, 415]), (16, [32, 154, 8, 39424, 486]), (17, [6, 406, 17, 41412, 495]), (18, [47, 125, 19, 111625, 349]), (19, [63, 125, 11, 86625, 275]), (20, [63, 125, 8, 63000, 380]), (21, [28, 340, 17, 161840, 144]), (22, [28, 66, 17, 31416, 183])])

# %%
x=5
for i in range(0, x):
    print(f"iter{i}")
    pprint(sorted(box_params.items(), key=lambda xx: xx[1][i]))
    #sorted_box = dict(sorted(box_params.items(), key=lambda xx: xx[1][i]))
    print()
# Out:
# iter0
# [(17, [6, 406, 17, 41412, 495]),
#  (21, [28, 340, 17, 161840, 144]),
#  (22, [28, 66, 17, 31416, 183]),
#  (15, [32, 154, 9, 44352, 415]),
#  (16, [32, 154, 8, 39424, 486]),
#  (8, [34, 234, 17, 135252, 286]),
#  (18, [47, 125, 19, 111625, 349]),
#  (19, [63, 125, 11, 86625, 275]),
#  (20, [63, 125, 8, 63000, 380]),
#  (1, [76, 406, 10, 308560, 356]),
#  (2, [76, 406, 7, 215992, 460]),
#  (12, [76, 234, 10, 177840, 414]),
#  (13, [76, 234, 7, 124488, 106]),
#  (10, [78, 85, 17, 112710, 416]),
#  (11, [78, 69, 17, 91494, 383]),
#  (0, [110, 406, 7, 312620, 242]),
#  (3, [110, 18, 10, 19800, 61]),
#  (4, [110, 18, 7, 13860, 168]),
#  (5, [110, 9, 24, 23760, 183]),
#  (6, [110, 9, 24, 23760, 184]),
#  (7, [110, 388, 5, 213400, 200]),
#  (9, [110, 82, 19, 171380, 383]),
#  (14, [110, 181, 19, 378290, 128])]
#
# iter1
# [(5, [110, 9, 24, 23760, 183]),
#  (6, [110, 9, 24, 23760, 184]),
#  (3, [110, 18, 10, 19800, 61]),
#  (4, [110, 18, 7, 13860, 168]),
# ...

# %%
# from pprint import pprint
# x=5
# for i in range(0, x):
#     print(f"iter{i}")
#     pprint(sorted(box_params.items(), key=lambda xx: xx[1][i]))
#     #sorted_box = dict(sorted(box_params.items(), key=lambda xx: xx[1][i]))
#     print()

# %%
# from pprint import pprint
# x=5
# for i in range(0, x):
#     print(f"iter{i}")
#     #pprint(sorted(box_params.items(), key=lambda xx: xx[1][i]))
#     sorted_box = dict(sorted(box_params.items(), key=lambda xx: xx[1][i]))
#     pprint(sorted_box)
#     print()

# %%
order= {
       "0":   {
                     "truck dimension":[574,238,165],
                     "number":49,
                     "boxes":[
                                   [304,7,49,104272,141],[304,7,49,104272,195],[311,8,165,410520,484],[311,6,165,307890,207],
                                   [328,14,62,284704,317],[328,210,84,5785920,226],[15,14,49,10290,425],[9,14,49,6174,173],
                                   [205,8,21,34440,415],[205,6,21,25830,339],[139,14,7,13622,401],[56,14,26,20384,164],
                                   [83,7,26,15106,192],[83,7,26,15106,294],[163,36,141,827388,177],[23,47,165,178365,368],
                                   [222,210,26,1212120,500],[222,210,9,419580,55],[180,210,46,1738800,398],[148,210,46,1429680,117],
                                   [163,94,141,2160402,152],[83,33,59,161601,257],[123,8,21,20664,313],[123,6,21,15498,279],
                                   [163,40,141,919320,175],[106,210,6,133560,181],[66,158,165,1720620,447],[17,158,165,443190,353],
                                   [189,9,33,56133,360],[189,5,33,31185,481],[163,21,82,280686,270],[163,21,59,201957,458],
                                   [83,33,40,109560,224],[83,33,22,60258,169],[83,21,44,76692,349],[17,14,156,37128,126],
                                   [17,14,9,2142,54],[106,18,29,55332,381],[105,47,165,814275,151],[163,160,24,625920,252],
                                   [163,31,24,121272,396],[105,47,165,814275,122],[106,192,5,101760,470],[13,47,132,80652,348],
                                   [13,47,33,20163,260],[106,98,24,249312,207],[106,94,24,239136,448],[46,12,44,24288,445],
                                   [37,12,44,19536,185]
                                   ],
                     "solution":[
                                   [270,21,21,304,7,49],[270,14,21,304,7,49],[263,6,0,311,8,165],[263,0,0,311,6,165],
                                   [246,14,103,328,14,62],[246,28,81,328,210,84],[255,14,21,15,14,49],[246,14,21,9,14,49],
                                   [369,20,0,205,8,21],[369,14,0,205,6,21],[246,14,70,139,14,7],[246,14,77,56,14,26],
                                   [302,21,77,83,7,26],[302,14,77,83,7,26],[83,47,24,163,36,141],[0,0,0,23,47,165],
                                   [352,28,55,222,210,26],[352,28,46,222,210,9],[394,28,0,180,210,46],[246,28,0,148,210,46],
                                   [83,144,24,163,94,141],[0,47,106,83,33,59],[246,20,0,123,8,21],[246,14,0,123,6,21],
                                   [83,104,24,163,40,141],[246,28,46,106,210,6],[17,80,0,66,158,165],[0,80,0,17,158,165],
                                   [385,19,70,189,9,33],[385,14,70,189,5,33],[83,83,83,163,21,82],[83,83,24,163,21,59],
                                   [0,47,22,83,33,40],[0,47,0,83,33,22],[0,59,62,83,21,44],[246,0,9,17,14,156],
                                   [246,0,0,17,14,9],[246,28,52,106,18,29],[23,0,0,105,47,165],[83,78,0,163,160,24],
                                   [83,47,0,163,31,24],[141,0,0,105,47,165],[246,46,52,106,192,5],[128,0,33,13,47,132],
                                   [128,0,0,13,47,33],[246,140,57,106,98,24],[246,46,57,106,94,24],[37,47,62,46,12,44],
                                   [0,47,62,37,12,44]
                                   ],
                     "total value":13901
              }
       }

# %%
truck_dimension = order["0"]['truck dimension']
packages = order["0"]['solution']
boxes = order["0"]['boxes']
total_value = order["0"]['total value']
box_count = order["0"]['number']
box_params = {}
for index in range(len(boxes)):
    box_params[index] = boxes[index]

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
decriment=30
def plot_3d_rectangles(rectangles, x_ticks, y_ticks, z_ticks, step_size):
    plt.interactive(True)
    fig = fig = plt.figure(figsize=(20, 30))
    ax = fig.add_subplot(111, projection='3d')

    for rect in rectangles:
        x, y, z, length, width, height,_ = rect
        ax.bar3d(x, y, z, length, width, height,shade=True)


    ax.set_xlabel('X-axis')
    ax.set_ylabel('Y-axis')
    ax.set_zlabel('Z-axis')
    ax.set_title('3D Rectangles')

    ax.set_xticks(np.arange(0, x_ticks + step_size-decriment, step_size-decriment))
    ax.set_yticks(np.arange(0, y_ticks + step_size, step_size))
    ax.set_zticks(np.arange(0, z_ticks + step_size, step_size))
    plt.show()

# %%
# Original list of lists
rank_1_Sol = [
    [0, 0, 0, 21, 163, 59], [21, 0, 0, 36, 141, 163], [57, 0, 0, 328, 210, 84],
    [57, 0, 84, 165, 158, 66], [385, 0, 0, 47, 165, 105], [57, 210, 0, 311, 8, 165],
    [432, 0, 0, 105, 47, 165], [368, 210, 0, 7, 26, 83], [432, 47, 0, 40, 163, 141],
    [0, 0, 59, 18, 106, 29], [57, 218, 0, 14, 9, 49], [71, 218, 0, 44, 12, 46],
    [57, 158, 84, 44, 37, 12], [472, 47, 0, 24, 106, 98], [101, 158, 84, 47, 33, 13],
    [222, 0, 84, 148, 210, 46], [385, 0, 105, 40, 83, 33], [375, 210, 0, 7, 26, 83],
    [496, 47, 0, 24, 160, 163], [472, 153, 0, 21, 82, 163], [57, 0, 150, 132, 47, 13],
    [432, 47, 141, 8, 123, 21], [189, 0, 150, 17, 156, 14], [385, 165, 0, 21, 44, 83],
    [115, 218, 0, 189, 5, 33], [115, 223, 0, 123, 6, 21], [222, 0, 130, 21, 205, 6],
    [243, 0, 130, 83, 22, 33], [238, 223, 0, 56, 14, 26]
]
# Calculate and append volumes using list comprehension
rank_1_Sol_with_volume = [box + [box[3] * box[4] * box[5]] for box in rank_1_Sol]

# Sort based on volume in decreasing order
sorted_result = sorted(rank_1_Sol_with_volume, key=lambda x: x[6], reverse=True)

# Display the sorted list
for item in sorted_result:
    print(item)
# Out:
# [57, 0, 0, 328, 210, 84, 5785920]
# [57, 0, 84, 165, 158, 66, 1720620]
# [222, 0, 84, 148, 210, 46, 1429680]
# [432, 47, 0, 40, 163, 141, 919320]
# [21, 0, 0, 36, 141, 163, 827388]
# [385, 0, 0, 47, 165, 105, 814275]
# [432, 0, 0, 105, 47, 165, 814275]
# [496, 47, 0, 24, 160, 163, 625920]
# [57, 210, 0, 311, 8, 165, 410520]
# [472, 153, 0, 21, 82, 163, 280686]
# [472, 47, 0, 24, 106, 98, 249312]
# [0, 0, 0, 21, 163, 59, 201957]
# [385, 0, 105, 40, 83, 33, 109560]
# [57, 0, 150, 132, 47, 13, 80652]
# [385, 165, 0, 21, 44, 83, 76692]
# [243, 0, 130, 83, 22, 33, 60258]
# [0, 0, 59, 18, 106, 29, 55332]
# [189, 0, 150, 17, 156, 14, 37128]
# [115, 218, 0, 189, 5, 33, 31185]
# [222, 0, 130, 21, 205, 6, 25830]
# [71, 218, 0, 44, 12, 46, 24288]
# [432, 47, 141, 8, 123, 21, 20664]
# [238, 223, 0, 56, 14, 26, 20384]
# [101, 158, 84, 47, 33, 13, 20163]
# [57, 158, 84, 44, 37, 12, 19536]
# [115, 223, 0, 123, 6, 21, 15498]
# [368, 210, 0, 7, 26, 83, 15106]
# [375, 210, 0, 7, 26, 83, 15106]
# ...

# %% [markdown]
# ### Plotting sloutions sorted by *Volume*

# %%
x_ticks = 600
y_ticks = 250
z_ticks = 250
step_size =50
index=3
# Plotting the rectangles with custom ticks
plot_3d_rectangles(sorted_result, x_ticks, y_ticks, z_ticks, step_size)

# %%
import copy
truck_dimension = [600,250,250]
SV= [i[3:] for i in sorted_result]
PP = [[0,0,0],[0,250,0]]
placed =[]
retry = []
best_point = []
container_dimention = copy.deepcopy(truck_dimension)
#sorted(rank_1_Sol_with_volume, key=lambda x: x[6], reverse=True)
for item in SV:
    for point in PP:
        if item[1] < container_dimention[1]:
            placed.extend([point+item])
            PP.extend([
                    [item[0],0,0],
                    [0,item[1],0],
                    [0,0,item[2]]
                    ])
            best_point.extend([point])
            PP.remove(point)
            #container_dimention[1] = container_dimention[1]-item[1] 
            break 
        elif item[0] < container_dimention[0]:
            placed.extend([point+item])
            PP.extend([
                    [item[0],0,0],
                    [0,item[1],0],
                    [0,0,item[2]]
                    ])
            #container_dimention[0] = container_dimention[0]-item[0]
            best_point.extend([point])
            PP.remove(point)  
            break
        elif item[2] < container_dimention[2]:
            placed.extend([point+item])
            PP.extend([
                    [item[0],0,0],
                    [0,item[1],0],
                    [0,0,item[2]]
                    ])
            #container_dimention[2] = container_dimention[2]-item[2] 
            best_point.extend([point])
            PP.remove(point) 
            break
        else:
            retry.extend(item)
            break
            

#placed
x_ticks = 600
y_ticks = 250
z_ticks = 250
step_size =50
index=3
# Plotting the rectangles with custom ticks
plot_3d_rectangles(placed, x_ticks, y_ticks, z_ticks, step_size)

# %%
import copy
truck_dimension = [600,250,250]
SV= [i[3:] for i in sorted_result]
PP = [[0,0,0]]
placed =[]
retry = []
best_point = []
container_dimention = copy.deepcopy(truck_dimension)
#sorted(rank_1_Sol_with_volume, key=lambda x: x[6], reverse=True)
for item in SV:
    for i in range(len(PP)):
        sorted_PW = sorted(PP, key=lambda x: x[1], reverse=True)
        sorted_PL = sorted(PP, key=lambda x: x[0], reverse=True)
        sorted_PH = sorted(PP, key=lambda x: x[2], reverse=True)
        for point in sorted_PW:
            if item[1]+sorted_PW[1] < container_dimention[1]:
                continue
            else:
                placed.extend([point+item])
                PP.extend([
                        [item[0],0,0],
                        [0,item[1],0],
                        [0,0,item[2]]
                        ])
                best_point.extend([point])
                PP.remove(point)
                #container_dimention[1] = container_dimention[1]-item[1] 
                break 
        if item[0]+point[0] < container_dimention[0]:
            placed.extend([point+item])
            PP.extend([
                    [item[0],0,0],
                    [0,item[1],0],
                    [0,0,item[2]]
                    ])
            #container_dimention[0] = container_dimention[0]-item[0]
            best_point.extend([point])
            PP.remove(point)  
            break
        elif item[2]+point[2] < container_dimention[2]:
            placed.extend([point+item])
            PP.extend([
                    [item[0],0,0],
                    [0,item[1],0],
                    [0,0,item[2]]
                    ])
            #container_dimention[2] = container_dimention[2]-item[2] 
            best_point.extend([point])
            PP.remove(point) 
            break
        else:
            retry.extend(item)
            break
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[34], line 16
#      14 sorted_PH = sorted(PP, key=lambda x: x[2], reverse=True)
#      15 for point in sorted_PW:
# ---> 16     if item[1]+sorted_PW[1] < container_dimention[1]:
#      17         continue
#      18     else:
#
# IndexError: list index out of range

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
decriment=30
def plot_3d_rectangle(rectangles, x_ticks, y_ticks, z_ticks, step_size):
    plt.interactive(True)
    fig = fig = plt.figure(figsize=(20, 30))
    ax = fig.add_subplot(111, projection='3d')

    for rect in rectangles:
        x, y, z, length, width, height,_ = rect
        ax.bar3d(x, y, z, length, width, height,shade=True)


    ax.set_xlabel('X-axis')
    ax.set_ylabel('Y-axis')
    ax.set_zlabel('Z-axis')
    ax.set_title('3D Rectangles')

    ax.set_xticks(np.arange(0, x_ticks + step_size-decriment, step_size-decriment))
    ax.set_yticks(np.arange(0, y_ticks + step_size-40, step_size-40))
    ax.set_zticks(np.arange(0, z_ticks + step_size-40, step_size-40))
    plt.show()



x_ticks = 600
y_ticks = 250
z_ticks = 250
step_size =50
index=3
# Plotting the rectangles with custom ticks
plot_3d_rectangle(placed[0:1]+placed[5:6], x_ticks, y_ticks, z_ticks, step_size)

# plot_3d_rectangle([[0, 0, 84, 36, 141, 163, 827388],
#  [165, 0, 0, 47, 165, 105, 814275],[0, 158, 0, 105, 47, 165, 814275],
#  [0, 0, 60, 24, 160, 163, 625920]
#  ], x_ticks, y_ticks, z_ticks, step_size)

# %%
placed[0:1]+placed[5:7]
# Out:
# [[0, 0, 0, 328, 210, 84, 5785920],
#  [165, 0, 0, 47, 165, 105, 814275],
#  [0, 158, 0, 105, 47, 165, 814275]]

# %%
plot_3d_rectangle([
    [0, 0, 0, 328, 210, 84, 5785920], [165, 0, 84, 47, 165, 105, 814275],[400, 158, 0, 105, 47, 165, 814275]
                   ]
                  , x_ticks, y_ticks, z_ticks, step_size)

# %%
size= [[304, 7, 49], [304, 7, 49], [311, 8, 165], [311, 6, 165], [328, 14, 62], [328, 210, 84], [15, 14, 49], [9, 14, 49], [205, 8, 21], [205, 6, 21], [139, 14, 7], [56, 14, 26], [83, 7, 26], [83, 7, 26]]
sorted_size=[]
for i in size:
    sorted_size.append(set(i))

# %%
zz=[270, 21, 21, 304, 7, 49]
z=[]

# %%
zz[3:]
# Out:
# [304, 7, 49]

# %%
z.append([zz[3:]+[(zz[3]*zz[4]*zz[5])]])

# %%
z
# Out:
# [[[304, 7, 49, 104272]]]
